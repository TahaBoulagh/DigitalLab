# %% [markdown]
# ## Job 0

# %%
class Personne:
    # constructor
    def __init__(self, prenom, nom):
        # Instance Variable
        self.prenom = prenom
        self.nom = nom
    
    # method 
    def Sepresenter(self):
        print("I'm a", self.prenom, self.nom)
        
    # Getters and Setters    
    def get_nom(self):
        return self.nom

    def set_nom(self, nom):
        self.nom = nom

    def get_prenom(self):
        return self.prenom

    def set_prenom(self, prenom):
        self.prenom = prenom
        
    # instancier des objets
obj1 = Personne("Yasser","Aitlaziz")
obj2 = Personne("Ilyass", "Elfourati")
    
    # Vérification
obj1.Sepresenter()
obj1.get_prenom()
# Out:
# I'm a Yasser Aitlaziz
# 'Yasser'

# %% [markdown]
# ## Job 02

# %%
# class Livre
class Livre:
    #Constructor
    def __init__(self, titre, reference):
        # Instance Variable
        self.titre = titre
        self.reference = reference
        self.reference.set_oeuvres(titre)
        
        
    # method print
    def print_titre(self):
        print(self.titre)
        
# class Personne        
class Personne:
    # constructor
    def __init__(self, prenom, nom):
        # Instance Variable
        self.prenom = prenom
        self.nom = nom
    
    # method 
    def Sepresenter(self):
        print("I'm a", self.prenom, self.nom)
        
    # Getters and Setters    
    def get_nom(self):
        return self.nom

    def set_nom(self, nom):
        self.nom = nom

    def get_prenom(self):
        return self.prenom

    def set_prenom(self, prenom):
        self.prenom = prenom
        
    #class Auteur derivé
class Auteur(Personne):
        #Constructor
    def __init__(self, prenom, nom, oeuvres):
            # Instance Variable
        self.nom = nom
        self.prenom = prenom
        self.oeuvres = oeuvres
    def get_oeuvres(self):
        return self.oeuvres
    def set_oeuvres(self,titre):
        self.ecrireunlivre(titre)
    def get_oeuvres(self) :
        return self.oeuvres
    def ecrireunlivre(self,titre):
        self.oeuvres.append(titre)

        
            
auteur1 = Auteur("yasser", "ait",['a','b'])            
livre1 = Livre("titre",auteur1)
livre2 = Livre("titrel3wissi",auteur1)
auteur1.get_oeuvres()
# Out:
# ['a', 'b', 'titre', 'titrel3wissi']

# %%
class Chat:
    def init(self, nom):
        self.nom = nom

    def ronronne(self):
        print(self.nom, 'fait: "prrrrr"')

    def caresse(self):
        self.ronronne()
class Enfant:
    def init(self, prénom, chat):
        self.prénom = prénom
        self.chat = chat


chat1 = Chat("mechh")
alice = Enfant("Alice", chat1)

# %% [markdown]
# ## Job 02.718

# %%
# class Livre
class Livre:
    #Constructor
    def __init__(self, titre, reference):
        # Instance Variable
        self.titre = titre
        self.reference = reference
        self.reference.set_oeuvres(titre)
        
        
    # method print
    def print_titre(self):
        print(self.titre)

# class Personne        
class Personne:
    # constructor
    def __init__(self, prenom, nom):
        # Instance Variable
        self.prenom = prenom
        self.nom = nom
    
    # method 
    def Sepresenter(self):
        print("I'm a", self.prenom, self.nom)
        
    # Getters and Setters    
    def get_nom(self):
        return self.nom

    def set_nom(self, nom):
        self.nom = nom

    def get_prenom(self):
        return self.prenom

    def set_prenom(self, prenom):
        self.prenom = prenom
        
    #class Auteur derivé
class Auteur(Personne):
        #Constructor
    def __init__(self, prenom, nom, oeuvres):
            # Instance Variable
        self.nom = nom
        self.prenom = prenom
        self.oeuvres = oeuvres
    def get_oeuvres(self):
        return self.oeuvres
    def set_oeuvres(self,titre):
        self.ecrireunlivre(titre)
    def get_oeuvres(self) :
        return self.oeuvres
    def ecrireunlivre(self,titre):
        self.oeuvres.append(titre)
 

 ##############################################################




class Personne:
    # constructor
    def __init__(self, prenom, nom):
        # Instance Variable
        self.prenom = prenom
        self.nom = nom
    
    # method 
    def Sepresenter(self):
        print("I'm a", self.prenom, self.nom)
        
    # Getters and Setters    
    def get_nom(self):
        return self.nom

    def set_nom(self, nom):
        self.nom = nom

    def get_prenom(self):
        return self.prenom

    def set_prenom(self, prenom):
        self.prenom = prenom
        
class Client(Personne) :
    # collection d'un client: liste des livres qui les a pris
    def __init__(self, collection):
        Personne.__init__(self,prenom, nom)
        self.collection = collection
    def get_collection(self,client):
        return self.collection
    def set_collection(self,collection):
        self.collection = collection
        
    def inventaire(self):
        return self.collection

class Bibliotheque:
    ## catalogue: dictionnaire (livre,quantite)
    def __init__(self, nom, catalogue):
        self.nom = nom
        self.catalogue = catalogue
    ## Getters and Setters for attributes
    def get_nom(self):
        return self.nom
    def set_nom(self,nom):
        self.nom = nom
    def get_catalogue(self):
        return self.catalogue
    def set_catalogue(self,catalogue):
        self.catalogue[catalogue[0]] = catalogue[1]
        
    def find_livre(self,livre, quantite):
        for e in self.catalogue.keys():
            if livre in e.get_oeuvres():
                return True
            
    def acheter_livre(self,auteur, livre, quantite):
        if self.find_livre(livre, quantite):
            self.catalogue[livre] = quantite
            
    def inventaire(self):
        return self.catalogue
    
    def louer(client, livre):
        if find_livre(livre, quantite):
            self.catalogue.append(livre)
            self.catalogue[livre] -=1
            
    def rendreLivres(self,client):
           for e in client.get_collection:
                self.catalogue[e] =+ 1

# %%
auteur1 = Auteur("yasser", "ait",['mojalad1'])
auteur2 = Auteur("Taha", "Boulaghla",['titre1','titre2']) 
auteur2.ecrireunlivre('titre3')
bib1 = Bibliotheque("bib1",{})
bib1.acheter_livre(auteur1,'mojalad1', 1)

# %% [markdown]
# ### Job 07.389

# %%
import numpy as np

# %%
class Board:
    # Constructeur de class Board
    def __init__(self, i, j):
        self.i = i
        self.j = j
        self.tableau = np.array([['O' for i in range(self.j)] for j in range(self.i) ])

    # methode play
    def play(self,n,couleur):
        if self.tableau[self.i-1][n] != 'O':
            print('Warning')
        for k in range(self.i):
            if self.tableau[k][n] =='O' :
                self.tableau[k][n] = couleur
                break
        # Verticale        
        if (self.tableau[k][n]==self.tableau[k-1][n]==self.tableau[k-2][n]==self.tableau[k-3][n]):
            print(couleur + 'Win')
            
        # Horizentale
        L = [couleur,couleur,couleur,couleur]
        if (list(self.tableau[k][n-3:n+1])==L) or (list(self.tableau[k][n-2:n+2])==L)or (list(self.tableau[k][n-1:n+3])==L) or (list(self.tableau[k][n:n+4])==L):
            print(couleur + 'Win')
            
        return self.tableau    
        # Diagonale
        L = [couleur,couleur,couleur,couleur]
        cd1 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k-2][n-2],self.tableau[k-3][n-3]]
        cd2 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k-2][n-2],self.tableau[k+1][n+1]]
        cd3 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k+2][n+2],self.tableau[k+1][n+1]]
        cd4 = [self.tableau[k][n],self.tableau[k+3][n+3],self.tableau[k+3][n+3],self.tableau[k+4][n+4]]  
        if(cd1 == L) or (cd2 == L) or (cd3 == L) or (cd4==L):
            print(couleur + 'Win')
        # Antidiagonale
        L = [couleur,couleur,couleur,couleur]
        cd5 = [self.tableau[k][n],self.tableau[k-1][n+1],self.tableau[k-2][n+2],self.tableau[k-3][n+3]]
        cd6 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k-2][n+2],self.tableau[k+1][n-1]]
        cd7 = [self.tableau[k][n],self.tableau[k+3][n-3],self.tableau[k+2][n-2],self.tableau[k+1][n-1]]
        cd8 = [self.tableau[k][n],self.tableau[k+4][n-4],self.tableau[k+2][n-2],self.tableau[k+1][n-1]] 
        if(cd5 == L) or (cd6 == L) or (cd7 == L) or (cd8==L):
            print(couleur + 'Win')
              
            
    # method print
    def print(self):
        return self.tableau

# %%
board = Board(4,6)
board.tableau


board.play(1,'J')
board.play(1,'J')
board.play(1,'J')
board.play(1,'J')
board.play(2,'J')
board.play(2,'J')
board.play(2,'J')
board.play(4,'J')
board.play(3,'J')

board.play(3,'J')

board.play(3,'J')
board.play(4,'J')
# Out:
# JWin
# JWin
# JWin
# array([['O', 'J', 'J', 'J', 'J', 'O'],
#        ['O', 'J', 'J', 'J', 'J', 'O'],
#        ['O', 'J', 'J', 'J', 'O', 'O'],
#        ['O', 'J', 'O', 'O', 'O', 'O']], dtype='<U1')

# %% [markdown]
# ### Job 20.085

# %%
class Board:
    # Constructeur de class Board
    def __init__(self, i, j):
        self.i = i
        self.j = j
        self.tableau = np.array([['O' for i in range(self.j)] for j in range(self.i) ])

    # methode play
    def play(self,n,couleur):
        if self.tableau[self.i-1][n] != 'O':
            print('Warning')
        for k in range(self.i):
            if self.tableau[k][n] =='O' :
                self.tableau[k][n] = couleur
                break
        # Verticale        
        if (self.tableau[k][n]==self.tableau[k-1][n]==self.tableau[k-2][n]==self.tableau[k-3][n]):
            print(couleur + 'Win')
            
        # Horizentale
        L = [couleur,couleur,couleur,couleur]
        if (list(self.tableau[k][n-3:n+1])==L) or (list(self.tableau[k][n-2:n+2])==L)or (list(self.tableau[k][n-1:n+3])==L) or (list(self.tableau[k][n:n+4])==L):
            print(couleur + 'Win')
            
        return self.tableau    
        # Diagonale
        L = [couleur,couleur,couleur,couleur]
        cd1 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k-2][n-2],self.tableau[k-3][n-3]]
        cd2 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k-2][n-2],self.tableau[k+1][n+1]]
        cd3 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k+2][n+2],self.tableau[k+1][n+1]]
        cd4 = [self.tableau[k][n],self.tableau[k+3][n+3],self.tableau[k+3][n+3],self.tableau[k+4][n+4]]  
        if(cd1 == L) or (cd2 == L) or (cd3 == L) or (cd4==L):
            print(couleur + 'Win')
        # Antidiagonale
        L = [couleur,couleur,couleur,couleur]
        cd5 = [self.tableau[k][n],self.tableau[k-1][n+1],self.tableau[k-2][n+2],self.tableau[k-3][n+3]]
        cd6 = [self.tableau[k][n],self.tableau[k-1][n-1],self.tableau[k-2][n+2],self.tableau[k+1][n-1]]
        cd7 = [self.tableau[k][n],self.tableau[k+3][n-3],self.tableau[k+2][n-2],self.tableau[k+1][n-1]]
        cd8 = [self.tableau[k][n],self.tableau[k+4][n-4],self.tableau[k+2][n-2],self.tableau[k+1][n-1]] 
        if(cd5 == L) or (cd6 == L) or (cd7 == L) or (cd8==L):
            print(couleur + 'Win')
              
            
    # method print
    def print(self):
        return self.tableau
    
    
    
    
class AI_One:
    # Constructor
    def __init__(self,board):
        self.board = board
    # Method Think
    def Think(self,board,couleur = 'R'):
        # verticale
        for j in range(len(self.tableau[1])):
            for i in range(len(self.tableau)):
                if (self.tableau[i][j] == self.tableau[i+1][j]==self.tableau[i+2][j]):
                    self.tableau[i+3][j] = couleur
        # Horizentale
        for j in range(len(self.tableau[1])):
            for i in range(len(self.tableau)):
                if (self.tableau[i][j] == self.tableau[i][j+1]==self.tableau[i][j+2]):
                    self.tableau[i][j+3] = couleur

        
        return self.tableau

# %%
board = Board(8,8)
board.tableau


board.play(1,'J')
AI_One(board)
AI_One.Think(board,'R')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-381-b64edcc0d4e0> in <module>
#       5 board.play(1,'J')
#       6 AI_One(board)
# ----> 7 AI_One.Think(board,'R')
#
# <ipython-input-380-2006d57a57ec> in Think(self, board, couleur)
#      58         for j in range(len(self.tableau[1])):
#      59             for i in range(len(self.tableau)):
# ---> 60                 if (self.tableau[i][j] == self.tableau[i+1][j]==self.tableau[i+2][j]):
#      61                     self.tableau[i+3][j] = couleur
#      62         # Horizentale
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
board = Board(8,8)
board.tableau


board.play(1,'J')
# Out:
# array([['O', 'J', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], dtype='<U1')
